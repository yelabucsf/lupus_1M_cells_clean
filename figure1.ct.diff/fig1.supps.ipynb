# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
version = "V6"

name = "CLUESImmVar_processed."+version

joined_pivot_perc=pd.read_csv(name+ '_joined_pivot_ct_perc.txt')

# %% [markdown]
# ## Correlation of replicates across batch

# %% [markdown]
# ## Mono/CD4 correlation in SLE patients

# %%
joined_sle=joined_pivot_perc[joined_pivot_perc.disease_cov=='sle']
print('Correlation of Tc and cM in SLE patients ' + str(joined_sle.Tc.corr(joined_sle.cM)))

joined_sle.plot.scatter('Tc', 'cM')
plt.savefig('supp.figures/cor.Tc.cM.pdf')
# Out:
# Correlation of Tc and cM in SLE patients -0.4080769921995803
